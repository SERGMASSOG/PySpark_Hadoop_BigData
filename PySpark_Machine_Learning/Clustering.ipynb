# %% [markdown]
# ## Customer Clustering with KMeans to Boost Business Strategy

# %%
# !pip install pandas==1.3.4
# !pip install scikit-learn==0.20.1
# Out:
# Collecting pandas==1.3.4
#   Using cached pandas-1.3.4.tar.gz (4.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\masso\AppData\Roaming\Python\Python312\site-packages)
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\masso\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#         File "C:\Users\masso\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\masso\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-t5l8_43b\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-t5l8_43b\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-t5l8_43b\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-t5l8_43b\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 19, in <module>
#       ModuleNotFoundError: No module named 'pkg_resources'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\masso\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\masso\AppData\Roaming\Python\Python312\site-packages)
# ERROR: Failed to build 'pandas' when getting requirements to build wheel
# Collecting scikit-learn==0.20.1
#   Using cached scikit-learn-0.20.1.tar.gz (9.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\masso\AppData\Roaming\Python\Python312\site-packages)
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\masso\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#         File "C:\Users\masso\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\masso\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-cecszv92\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-cecszv92\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-cecszv92\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\masso\AppData\Local\Temp\pip-build-env-cecszv92\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 12, in <module>
#       ModuleNotFoundError: No module named 'pkg_resources'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\masso\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\masso\AppData\Roaming\Python\Python312\site-packages)
# ERROR: Failed to build 'scikit-learn' when getting requirements to build wheel

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %% [markdown]
# ## Clustering demo with generated sample data

# %%
# Generate sample data
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=0)

# %%
# Apply k-means clustering
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.37324398,  7.75368871],
#        [ 0.94973532,  4.41906906],
#        [ 1.98258281,  0.86771314],
#        [-1.58438467,  2.83081263]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=400, color='black')
plt.show()

# %%
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/customers.csv"
df = pd.read_csv(URL)

# %%
df.sample(5)
# Out:
#      Fresh_Food  Milk  Grocery  Frozen_Food
# 17         5876  6157     2933          839
# 242       18226   659     2914         3752
# 16         1020  8816    12121          134
# 363        4627   997     4438          191
# 90        11405   596     1638         3347

# %%
df.shape
# Out:
# (440, 4)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Fresh_Food'}>,
#         <Axes: title={'center': 'Milk'}>],
#        [<Axes: title={'center': 'Grocery'}>,
#         <Axes: title={'center': 'Frozen_Food'}>]], dtype=object)

# %%
number_of_clusters = 3

# %%
cluster = KMeans(n_clusters = number_of_clusters)

# %%
result = cluster.fit_transform(df)

# %%
cluster.cluster_centers_
# Out:
# array([[ 7357.32352941,  4503.07941176,  6442.45294118,  2495.28529412],
#        [12841.6       , 26289.36      , 35155.68      ,  3522.36      ],
#        [32768.01333333,  4827.68      ,  5723.14666667,  5535.92      ]])

# %%
df['cluster_number'] = cluster.predict(df)

# %%
df.sample(5)
# Out:
#      Fresh_Food  Milk  Grocery  Frozen_Food  cluster_number
# 113       14438  2295     1733         3220               0
# 213        3317  6602     6861         1329               0
# 175        2343  7845    11874           52               0
# 224        7274   659     1499          784               0
# 1          7057  9810     9568         1762               0

# %%
df.cluster_number.value_counts()
# Out:
# cluster_number
# 0    340
# 2     75
# 1     25
# Name: count, dtype: int64

# %% [markdown]
# <!--
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-04-14|0.1|Ramesh Sannareddy|Initial Version Created|
# |2023-06-20|0.3|Vicky Kuo|Proofreading|
# -->
